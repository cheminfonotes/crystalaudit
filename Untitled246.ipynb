# %%
# !pip install git+https://github.com/cheminfonotes/crystalaudit.git
# Out:
# Collecting git+https://github.com/cheminfonotes/crystalaudit.git
#   Cloning https://github.com/cheminfonotes/crystalaudit.git to /tmp/pip-req-build-usp0a62b
#   Running command git clone --filter=blob:none --quiet https://github.com/cheminfonotes/crystalaudit.git /tmp/pip-req-build-usp0a62b
#   Resolved https://github.com/cheminfonotes/crystalaudit.git to commit 5c5b2dc0c4e0a408187cf941404ac470ee7e0305
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: gemmi>=0.6 in /usr/local/lib/python3.12/dist-packages (from crystalaudit==0.1.0) (0.7.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from crystalaudit==0.1.0) (2.4.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from crystalaudit==0.1.0) (3.0.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from crystalaudit==0.1.0) (1.9.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from crystalaudit==0.1.0) (3.10.9)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from crystalaudit==0.1.0) (2.34.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->crystalaudit==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->crystalaudit==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->crystalaudit==0.1.0) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->crystalaudit==0.1.0) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->crystalaudit==0.1.0) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->crystalaudit==0.1.0) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /usr/local/lib/python3.12/dist-packages (from matplotlib->crystalaudit==0.1.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->crystalaudit==0.1.0) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->crystalaudit==0.1.0) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->crystalaudit==0.1.0) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.12/dist-packages (from requests->crystalaudit==0.1.0) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /usr/local/lib/python3.12/dist-packages (from requests->crystalaudit==0.1.0) (2026.5.20)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->crystalaudit==0.1.0) (1.17.1)
# Requirement already satisfied: joblib>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->crystalaudit==0.1.0) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->crystalaudit==0.1.0) (2.22.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->crystalaudit==0.1.0) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->crystalaudit==0.1.0) (1.17.0)

# %%
import crystalaudit as ca
ca.analyze("1UBQ").show()
# Out:
#      pid chain  resnum resname   class_key       value    expected      abs_z  \
# 0   1UBQ     A      21     ASP     ASP:psi  148.435374  -35.893506  18.759189
# 1   1UBQ     A      30     ILE     ILE:psi  -39.563969  131.178560   7.814250
# 2   1UBQ     A      23     ILE     ILE:psi  -37.209914  131.178560   7.706514
# 3   1UBQ     A      56     LEU     LEU:psi  -36.205131  133.507722   6.455487
# 4   1UBQ     A      31     GLN     GLN:psi  -48.627696  133.438345   5.864587
# 5   1UBQ     A      64     GLU     GLU:phi   66.897344 -101.236147   5.511841
# 6   1UBQ     A       8     LEU     LEU:psi   -6.935906  133.507722   5.342153
# 7   1UBQ     A      40     GLN     GLN:psi  -10.469230  133.438345   4.743099
# 8   1UBQ     A       9     THR     THR:psi   14.929594  140.896931   4.348790
# 9   1UBQ     A      52     ASP  ASP:N-CA-C  120.738084  111.386089   4.338254
# 10  1UBQ     A      75     GLY     GLY:psi  125.558005   23.120889   3.881708
# 11  1UBQ     A      53     GLY     GLY:phi  -82.925236  100.733980   3.817760
# 12  1UBQ     A      42     ARG     ARG:C-O    1.296177    1.229000   3.535615
#
#    attribution  confidence  p_biological  p_packing   p_error  \
# 0   biological    0.776667      0.776667        0.0  0.223333
# 1   biological    1.000000      1.000000        0.0  0.000000
# 2   biological    1.000000      1.000000        0.0  0.000000
# 3   biological    1.000000      1.000000        0.0  0.000000
# 4   biological    1.000000      1.000000        0.0  0.000000
# 5   biological    1.000000      1.000000        0.0  0.000000
# 6   biological    1.000000      1.000000        0.0  0.000000
# 7   biological    0.990000      0.990000        0.0  0.010000
# 8   biological    0.900000      0.900000        0.0  0.100000
# 9   biological    0.896667      0.896667        0.0  0.103333
# 10       error    1.000000      0.000000        0.0  1.000000
# 11  biological    0.940000      0.940000        0.0  0.060000
# 12  biological    0.950000      0.950000        0.0  0.050000
#
#                                           explanation
# 0   Buried, no symmetry contact — possible functio...
# 1   Buried, no symmetry contact — possible functio...
# 2   Buried, no symmetry contact — possible functio...
# 3   Buried, no symmetry contact — possible functio...
# 4   Buried, no symmetry contact — possible functio...
# 5   Buried, no symmetry contact — possible functio...
# 6   Buried, no symmetry contact — possible functio...
# 7   Buried, no symmetry contact — possible functio...
# 8   Buried, no symmetry contact — possible functio...
# 9   Buried, no symmetry contact — possible functio...
# 10  High relative B (z=3.9) / reso 1.80 A — likely...
# 11  Buried, no symmetry contact — possible functio...
# 12  Buried, no symmetry contact — possible functio...
# <crystalaudit.Result 1UBQ: 13 outliers, counts={'biological': 12, 'error': 1}>

# %%
import crystalaudit as ca
ca.analyze("3ONS").show()
# Out:
#     pid chain  resnum resname class_key       value    expected     abs_z  \
# 0  3ONS     A      56     LEU   LEU:psi  -38.315717  139.541887  8.400236
# 1  3ONS     A       8     LEU   LEU:psi  -35.576908  139.541887  8.270882
# 2  3ONS     A      52     ASP   ASP:psi  148.481762  -26.279731  8.203654
# 3  3ONS     A      21     ASP   ASP:psi  138.211109  -26.279731  7.721529
# 4  3ONS     A      30     ILE   ILE:psi  -38.208759  128.451380  6.999257
# 5  3ONS     A      23     ILE   ILE:psi  -36.863562  128.451380  6.942763
# 6  3ONS     A      64     GLU   GLU:phi   65.746731  -99.376298  5.258783
# 7  3ONS     A      31     GLN   GLN:psi  -40.854677  130.131321  3.809008
#
#   attribution  confidence  p_biological  p_packing   p_error  \
# 0  biological    0.856667      0.856667        0.0  0.143333
# 1       error    0.996667      0.003333        0.0  0.996667
# 2  biological    0.793333      0.793333        0.0  0.206667
# 3  biological    0.940000      0.940000        0.0  0.060000
# 4  biological    0.980000      0.980000        0.0  0.020000
# 5  biological    0.980000      0.980000        0.0  0.020000
# 6  biological    0.990000      0.990000        0.0  0.010000
# 7  biological    0.990000      0.990000        0.0  0.010000
#
#                                          explanation
# 0  Buried, no symmetry contact — possible functio...
# 1  High relative B (z=2.1) / reso 1.80 A — likely...
# 2  Buried, no symmetry contact — possible functio...
# 3  Buried, no symmetry contact — possible functio...
# 4  Buried, no symmetry contact — possible functio...
# 5  Buried, no symmetry contact — possible functio...
# 6  Buried, no symmetry contact — possible functio...
# 7  Buried, no symmetry contact — possible functio...
# <crystalaudit.Result 3ONS: 8 outliers, counts={'biological': 7, 'error': 1}>

# %%
import crystalaudit as ca
ca.analyze("1CRN").show()
# Out:
#     pid chain  resnum resname class_key       value    expected     abs_z  \
# 0  1CRN     A      26     CYS   CYS:psi  -31.686198  151.032833  7.693521
# 1  1CRN     A      16     CYS   CYS:psi  -36.000832  151.032833  7.506278
# 2  1CRN     A      41     PRO   PRO:psi  162.749132   -1.245668  4.787162
# 3  1CRN     A      22     PRO   PRO:psi  146.617514   -1.245668  4.316265
#
#   attribution  confidence  p_biological  p_packing  p_error  \
# 0  biological         1.0           1.0        0.0      0.0
# 1  biological         1.0           1.0        0.0      0.0
# 2  biological         1.0           1.0        0.0      0.0
# 3  biological         1.0           1.0        0.0      0.0
#
#                                          explanation
# 0  Buried, no symmetry contact — possible functio...
# 1  Buried, no symmetry contact — possible functio...
# 2  Buried, no symmetry contact — possible functio...
# 3  Buried, no symmetry contact — possible functio...
# <crystalaudit.Result 1CRN: 4 outliers, counts={'biological': 4}>
